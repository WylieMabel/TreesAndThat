# %%
import time
from multiprocessing import Process
from modelScript import fullModelRun

# %%
process_1 = Process(target=fullModelRun, args=(1, 0, 2, 3,"new_temp_data.csv", 10))
process_2 = Process(target=fullModelRun, args=(2, 0, 2, 3,"new_temp_data.csv", 10))
process_3 = Process(target=fullModelRun, args=(3, 0, 2, 3,"new_temp_data.csv", 10))
process_4 = Process(target=fullModelRun, args=(4, 0, 2, 3,"new_temp_data.csv", 10))
process_5 = Process(target=fullModelRun, args=(5, 0, 2, 3,"new_temp_data.csv", 10))
process_6 = Process(target=fullModelRun, args=(6, 0, 2, 3,"new_temp_data.csv", 10))
process_7 = Process(target=fullModelRun, args=(7, 0, 2, 3,"new_temp_data.csv", 10))
process_8 = Process(target=fullModelRun, args=(8, 0, 2, 3,"new_temp_data.csv", 10))
process_9 = Process(target=fullModelRun, args=(9, 0, 2, 3,"new_temp_data.csv", 10))
process_10 = Process(target=fullModelRun, args=(10, 0, 2, 3,"new_temp_data.csv", 10))

# %%
# %%time

# Starts both processes
process_1.start()
process_2.start()
process_3.start()
process_4.start()
process_5.start()
process_6.start()
process_7.start()
process_8.start()
process_9.start()
process_10.start()
# Out:
# CPU times: user 17 ms, sys: 65.1 ms, total: 82.1 ms
# Wall time: 215 ms
# year: 0
# year: 0
# year: 0
# year: 0
# year: 0
# year: 0
# year: 0year: 0
#
# year: 0
# year: 0
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# year: 1
# year: 1
# year: 1
# year: 1
# year: 1
# year: 1
# year: 1
# year: 1
# year: 1
# year: 1
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# [3 3 3 ..., 3 3 3]
# [0 0 0 ..., 0 0 0]
# ...
