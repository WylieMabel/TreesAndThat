# %%
import time
from multiprocessing import Process
from modelScript import fullModelRun, singleModelRun
import numpy as np

# set climate scenarios
current_clim={
        #------------------#
        # dry season dates #
        'canicula_start':0,
        'canicula_end':140, 
        'canicula_start_expected':0,
        'canicula_end_expected':140, 
        #----------------#
        # rainfall stats #
        # Times are all in hours.
        'mean_interstorm_wet':4*24,
        'mean_storm_wet':2*24,
        'mean_raindpth_wet':10,
        'mean_interstorm_dry':10*24,
        'mean_storm_dry':0.5*24,
        'mean_raindpth_dry':1,
        #-------------------#
        # temperature shift #
        'tempshift':np.array(365*[0.])
    }

#have two plausible versions of this that we switch between.

warm_clim={
        #------------------#
        # dry season dates #
        'canicula_start':0,
        'canicula_end':160, 
        'canicula_start_expected':0,
        'canicula_end_expected':140, 
        #----------------#
        # rainfall stats #
        # Times are all in hours.
        'mean_interstorm_wet':8*24,
        'mean_storm_wet':3*24,
        'mean_raindpth_wet':15,
        'mean_interstorm_dry':10*24,
        'mean_storm_dry':0.5*24,
        'mean_raindpth_dry':1,
        #-------------------#
        # temperature shift #
        'tempshift':np.array(365*[2.])
    }

# set social scenarios - Desperation Threshold, Jealousy Tolerance, Grace Period, Social Scenario Name
no_desp_scen= [0,5,3, "No Desperation"]
high_jealousy_tolerance_scen = [10,5,3, "High Jealousy Tolerance"]
low_jealousy_tolerance_scen = [2,5,3, "Low Jealousy Tolerance"]

# %%
# contains all combinations of parameters
combination_arrays = [
    [current_clim, 5, no_desp_scen],
    [current_clim, 5, high_jealousy_tolerance_scen],
    [current_clim, 5, low_jealousy_tolerance_scen],
    [current_clim, 10, no_desp_scen],
    [current_clim, 10, high_jealousy_tolerance_scen],
    [current_clim, 10, low_jealousy_tolerance_scen],
    [current_clim, 20, no_desp_scen],
    [current_clim, 20, high_jealousy_tolerance_scen],
    [current_clim, 20, low_jealousy_tolerance_scen],
    [warm_clim, 5, no_desp_scen],
    [warm_clim, 5, high_jealousy_tolerance_scen],
    [warm_clim, 5, low_jealousy_tolerance_scen],
    [warm_clim, 10, no_desp_scen],
    [warm_clim, 10, high_jealousy_tolerance_scen],
    [warm_clim, 10, low_jealousy_tolerance_scen],
    [warm_clim, 20, no_desp_scen],
    [warm_clim, 20, high_jealousy_tolerance_scen],
    [warm_clim, 20, low_jealousy_tolerance_scen]
]

# %%
# runs one model run for the given model parameters and outputs the graphs of WSA spread
singleModelRun(combination_arrays[0][0],combination_arrays[0][1],combination_arrays[0][2],"new_temp_data.csv", 3)
# Out:
# year: 0
# year: 1
# year: 2
# (      owner-id  Year  ...  ClimateScenario                    UniqueID
#  0          0.0     0  ...  Current Climate  2023-12-01 12:11:07.259879
#  1          0.0     1  ...  Current Climate  2023-12-01 12:11:07.259879
#  2          0.0     2  ...  Current Climate  2023-12-01 12:11:07.259879
#  3          0.0     3  ...  Current Climate  2023-12-01 12:11:07.259879
#  4          1.0     0  ...  Current Climate  2023-12-01 12:11:07.259879
#  ...        ...   ...  ...              ...                         ...
#  3195     798.0     3  ...  Current Climate  2023-12-01 12:11:07.259879
#  3196     799.0     0  ...  Current Climate  2023-12-01 12:11:07.259879
#  3197     799.0     1  ...  Current Climate  2023-12-01 12:11:07.259879
#  3198     799.0     2  ...  Current Climate  2023-12-01 12:11:07.259879
#  3199     799.0     3  ...  Current Climate  2023-12-01 12:11:07.259879
#
#  [3200 rows x 12 columns],
#  [[array([[ 0.,  0.,  0., ...,  0.,  0.,  0.],
# ...

# %%
# sets up multiprocessors with commands to run

process_1 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_2 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_3 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_4 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_5 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_6 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_7 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_8 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_9 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))
process_10 = Process(target=fullModelRun, args=(combination_arrays,"new_temp_data.csv", 30))

# %%
# %%time

# Starts all processes
process_1.start()
process_2.start()
process_3.start()
process_4.start()
process_5.start()
process_6.start()
process_7.start()
process_8.start()
process_9.start()
process_10.start()
